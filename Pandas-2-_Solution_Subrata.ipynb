# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Pandas-2<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# ## Table of Content
# 1. **[Reshape](#Reshape)**
# 2. **[Pivoting](#Pivoting)**
# 3. **[Duplicating](#Duplicating)**
# 4. **[Replacing](#Replacing)**
# 5. **[Indexing](#Indexing)**
# 6. **[Summary Statistics](#Summary_Statistics)**
# 7. **[Merge, Join, Concatenate](#merge)**

# %% [markdown]
# <a id='Reshape'></a>
# ## 1. Reshape

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Write a program to reshape the given data frame using the melt function
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Day</th>
# <th>ICIC</th>
# <th>HDFC</th>
# </tr>
# <tr>
# <td>MON</td>
# <td>1129</td>
# <td>191</td>
# </tr>
# <tr>
# <td>TUES</td>
# <td>1132</td>
# <td>192</td>
# </tr>
# <tr>
# <td>WED</td>
# <td>1134</td>
# <td>190</td>
# </tr>
# <tr>
# <td>THU</td>
# <td>1152</td>
# <td>190</td>
# </tr>
# <tr>
# <td>FRI</td>
# <td>1152</td>
# <td>188</td>
# </tr>
#
# </table>

# %%
import pandas as pd
DATA= {'DAY':['MON','TUES','WED','THU','FRI'],'ICIC':[1129,1132,1134,1152,1152],"HDFC":[191,192,190,190,188]}
df= pd.DataFrame(DATA)
df
# Out:
#     DAY  ICIC  HDFC
# 0   MON  1129   191
# 1  TUES  1132   192
# 2   WED  1134   190
# 3   THU  1152   190
# 4   FRI  1152   188

# %%
df_melt=df.melt(id_vars =['HDFC','ICIC'])
print(df_melt)
# Out:
#    HDFC  ICIC variable value
# 0   191  1129      DAY   MON
# 1   192  1132      DAY  TUES
# 2   190  1134      DAY   WED
# 3   190  1152      DAY   THU
# 4   188  1152      DAY   FRI

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Stack the data frame at level 1
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# header = pd.MultiIndex.from_product([['First_Semester','Second_Semester'],['Machine Learning','Python']])
#
# data=([[12,45,67,56],[78,89,45,67],[45,67,89,90],[67,44,56,55]])
#
# df_student = pd.DataFrame(data,
#                   index=['John','Bobby','Cathrine','Jack'],
#                   columns=header)
# df_student

# %%
header = pd.MultiIndex.from_product([['First_Semester','Second_Semester'],['Machine Learning','Python']])
data=([[12,45,67,56],[78,89,45,67],[45,67,89,90],[67,44,56,55]])
df_student = pd.DataFrame(data, index=['John','Bobby','Cathrine','Jack'], columns=header)
df_student
# Out:
#            First_Semester         Second_Semester
#          Machine Learning Python Machine Learning Python
# John                   12     45               67     56
# Bobby                  78     89               45     67
# Cathrine               45     67               89     90
# Jack                   67     44               56     55

# %%
df_Stack=df_student.stack()
df_Stack
# Out:
#                            First_Semester  Second_Semester
# John     Machine Learning              12               67
#          Python                        45               56
# Bobby    Machine Learning              78               45
#          Python                        89               67
# Cathrine Machine Learning              45               89
#          Python                        67               90
# Jack     Machine Learning              67               56
#          Python                        44               55

# %% [markdown]
# <a id='Pivoting'></a>
# ## 2. Pivoting

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3. Find the average sales for each store
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
yields= {'Store':['A','B','A','C','D','A','D','A','C','B'],
         'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
        'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
df_yields= pd.DataFrame(yields,columns=['Store','Location','Sales'])
df_yields
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
import numpy as np
pd.pivot_table(df_yields,index=['Store'],values=['Sales'],aggfunc=np.sum)
# Out:
#         Sales
# Store
# A      255000
# B      115000
# C      179000
# D      174000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Use Sales, Store and Location from the given data frame and compute 'Mean Sales' for each store by location.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
yields1= {'Store':['A','B','A','C','D','A','D','A','C','B'],
         'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
        'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
df_yields1= pd.DataFrame(yields,columns=['Store','Location','Sales'])
df_yields1
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
import numpy as np
pd.pivot_table(df_yields,index=['Store'],values=['Sales'],aggfunc='mean',columns=['Location'])
# Out:
#             Sales
# Location    Delhi Hyderabad   Mumbai     Pune
# Store
# A         87000.0   50000.0  40000.0  78000.0
# B             NaN       NaN      NaN  57500.0
# C             NaN       NaN  89500.0      NaN
# D             NaN   85000.0      NaN  89000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Compute “minimum” sales for each store by location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
yields2= {'Store':['A','B','A','C','D','A','D','A','C','B'],
         'Location':['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi','Hyderabad','Pune','Mumbai','Pune'],
        'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
df_yields2= pd.DataFrame(yields,columns=['Store','Location','Sales'])
df_yields2
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
import numpy as np
pd.pivot_table(df_yields2,index=['Store'],values=['Sales'],aggfunc=np.min,columns=['Location'])
# Out:
#             Sales
# Location    Delhi Hyderabad   Mumbai     Pune
# Store
# A         87000.0   50000.0  40000.0  78000.0
# B             NaN       NaN      NaN  45000.0
# C             NaN       NaN  89000.0      NaN
# D             NaN   85000.0      NaN  89000.0

# %% [markdown]
# <a id='Duplicating'></a>
# ## 3. Duplicating

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Find duplicate rows based on all columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
Data2= {'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],
       'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],
        'City':['sydeny','Chicago','New York','Chicago','Chicago','Texas','Londan','Chicago']}
df3= pd.DataFrame(Data2,columns=['Name','Salary','City'])
df3
# Out:
#       Name  Salary      City
# 0     John    3400    sydeny
# 1   Robert    3000   Chicago
# 2     Aadi    1600  New York
# 3   Robert    3000   Chicago
# 4   Robert    3000   Chicago
# 5   Robert    3000     Texas
# 6     Aadi    4000    Londan
# 7  Sachine    3000   Chicago

# %%
df3.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df3.duplicated().value_counts()
# Out:
# False    6
# True     2
# dtype: int64

# %%
duplicate = df3[df3.duplicated()]

# %%
duplicate
# Out:
#      Name  Salary     City
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Select duplicate rows based on all columns except the last occurrence of the duplicate.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
Data2= {'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],
       'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],
        'City':['sydeny','Chicago','New York','Chicago','Chicago','Texas','Londan','Chicago']}
df3= pd.DataFrame(Data2,columns=['Name','Salary','City'])
df3
# Out:
#       Name  Salary      City
# 0     John    3400    sydeny
# 1   Robert    3000   Chicago
# 2     Aadi    1600  New York
# 3   Robert    3000   Chicago
# 4   Robert    3000   Chicago
# 5   Robert    3000     Texas
# 6     Aadi    4000    Londan
# 7  Sachine    3000   Chicago

# %%
Duplicate2= df3[df3.duplicated(keep='last')]
Duplicate2
# Out:
#      Name  Salary     City
# 1  Robert    3000  Chicago
# 3  Robert    3000  Chicago

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Find & select duplicated rows based on a two column names (salary and city)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
Data2= {'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],
       'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],
        'City':['sydeny','Chicago','New York','Chicago','Chicago','Texas','Londan','Chicago']}
df3= pd.DataFrame(Data2,columns=['Name','Salary','City'])
df3
# Out:
#       Name  Salary      City
# 0     John    3400    sydeny
# 1   Robert    3000   Chicago
# 2     Aadi    1600  New York
# 3   Robert    3000   Chicago
# 4   Robert    3000   Chicago
# 5   Robert    3000     Texas
# 6     Aadi    4000    Londan
# 7  Sachine    3000   Chicago

# %%
duplicate3=df3[df3.duplicated(['Salary','City'])]
duplicate3
# Out:
#       Name  Salary     City
# 3   Robert    3000  Chicago
# 4   Robert    3000  Chicago
# 7  Sachine    3000  Chicago

# %% [markdown]
# <a id='Replacing'></a>
# ## 4. Replacing

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9.  Replace 'football' in the column tournament with 'hockey'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
data5= {'Days':['Mon','Tues','Wed','Thurs','Fri'],'Tournament':['Football','Cricket','Football','Football','Cricket']}
df5=pd.DataFrame(data5,columns=['Days','Tournament'])
df5
# Out:
#     Days Tournament
# 0    Mon   Football
# 1   Tues    Cricket
# 2    Wed   Football
# 3  Thurs   Football
# 4    Fri    Cricket

# %%
dict_tournament={'Football':'Hockey'}
df5['Tournament'].replace(dict_tournament,inplace=True)
df5
# Out:
#     Days Tournament
# 0    Mon     Hockey
# 1   Tues    Cricket
# 2    Wed     Hockey
# 3  Thurs     Hockey
# 4    Fri    Cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10.  Replace all 0 in column gender with male and 1 with female
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Num_Children</th>
# <th>Gender</th>
# </tr>
# <tr>
# <td>John</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>4</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Johny</td>
# <td>5</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>3</td>
# <td>1</td>
# </tr>
#
# </table>

# %%
data6={'Name':['John','Robert','Johny','Mia'],'Num_Children':[0,4,5,3],'Gender':[0,0,0,1]}
df6=pd.DataFrame(data6,columns=['Name','Num_Children','Gender'])
df6
# Out:
#      Name  Num_Children  Gender
# 0    John             0       0
# 1  Robert             4       0
# 2   Johny             5       0
# 3     Mia             3       1

# %%
dict_gender= {0:'Male',1:'Female'}
df6['Gender'].replace(dict_gender,inplace=True)
df6
# Out:
#      Name  Num_Children  Gender
# 0    John             0    Male
# 1  Robert             4    Male
# 2   Johny             5    Male
# 3     Mia             3  Female

# %% [markdown]
# <a id='Indexing'></a>
# ## 5. Indexing

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 11.  Get the 'Name' and 'City' columns as an index from the below data frame
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>City</th>
# <th>Sales</th>
# <th>Expenses</th>
# </tr>
# <tr>
# <td>John</td>
# <td>New York</td>
# <td>50000</td>
# <td>42000</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>Chicago</td>
# <td>52000</td>
# <td>43000</td>
# </tr>
# <tr>
# <td>Jony</td>
# <td>Texas</td>
# <td>90000</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>California</td>
# <td>34000</td>
# <td>44000</td>
# </tr>
# <tr>
# <td>Edward</td>
# <td>Sydney</td>
# <td>42000</td>
# <td>38000</td>
# </tr>
# <tr>
# <td>Thomas</td>
# <td>New York</td>
# <td>72000</td>
# <td>39000</td>
# </tr>
# <tr>
# <td>Ethan</td>
# <td>Chicago</td>
# <td>49000</td>
# <td>42000</td>
# </tr>
# <tr>
# <td>Olivia</td>
# <td>Sydeney</td>
# <td>55000</td>
# <td>60000</td>
# </tr>
# <tr>
# <td>Arun</td>
# <td>California</td>
# <td>67000</td>
# <td>39000</td>
# </tr>
# <tr>
# <td>Ankita</td>
# <td>Texas</td>
# <td>65000</td>
# <td>44000</td>
# </tr>
# <tr>
# <td>Paulo</td>
# <td>Chicago</td>
# <td>67000</td>
# <td>45000</td>
# </tr>
#
# </table>

# %%
data5={'Name':['John','Robert','Jony','Mia','Edward','Thomas','Ethan','Olivia','Arun','Ankita','Paulo'],
      'City':['New York','Chicago','Texas','California','Sydney','New York','Chicago','Sydeny','California','Texas','Chicago'],
      'Sales':[50000,52000,90000,34000,42000,72000,49000,55000,67000,65000,67000],
      'Expences':[42000,43000,50000,44000,38000,39000,42000,60000,39000,44000,45000]}
df_x=pd.DataFrame(data5)
df_x
# Out:
#       Name        City  Sales  Expences
# 0     John    New York  50000     42000
# 1   Robert     Chicago  52000     43000
# 2     Jony       Texas  90000     50000
# 3      Mia  California  34000     44000
# 4   Edward      Sydney  42000     38000
# 5   Thomas    New York  72000     39000
# 6    Ethan     Chicago  49000     42000
# 7   Olivia      Sydeny  55000     60000
# 8     Arun  California  67000     39000
# 9   Ankita       Texas  65000     44000
# 10   Paulo     Chicago  67000     45000

# %%
df_index=df_x.set_index(['Name','City'])
df_index
# Out:
#                    Sales  Expences
# Name   City
# John   New York    50000     42000
# Robert Chicago     52000     43000
# Jony   Texas       90000     50000
# Mia    California  34000     44000
# Edward Sydney      42000     38000
# Thomas New York    72000     39000
# Ethan  Chicago     49000     42000
# Olivia Sydeny      55000     60000
# Arun   California  67000     39000
# Ankita Texas       65000     44000
# Paulo  Chicago     67000     45000

# %% [markdown]
# <a id='Summary_Statistics'></a>
# ## 6. Summary Statistics

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 12.  Get the descriptive statistics for the sales column from the given data frame
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
data8={'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],
      'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],
      'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']}
df_stats=pd.DataFrame(data8)
df_stats
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
df_stats.describe()
# Out:
#               Sales
# count     12.000000
# mean   48166.666667
# std    19385.249000
# min    22000.000000
# 25%    28500.000000
# 50%    56000.000000
# 75%    61750.000000
# max    78000.000000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 13.  Save median of sales for each season in the data frame
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
data8={'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],
      'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],
      'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']}
df_stats1=pd.DataFrame(data8)
df_stats1
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
df_stats1.median(axis=1)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_13664/1132474885.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_stats1.median(axis=1)
# 0     22000.0
# 1     27000.0
# 2     25000.0
# 3     29000.0
# 4     35000.0
# 5     67000.0
# 6     78000.0
# 7     67000.0
# 8     56000.0
# 9     56000.0
# 10    56000.0
# 11    60000.0
# dtype: float64

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 14. Store descriptive statistics for categorical data to a data frame
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
data8={'Month':['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],
      'Sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],
      'Seasons':['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']}
df_stats2=pd.DataFrame(data8)
df_stats2
# Out:
#    Month  Sales Seasons
# 0    Jan  22000  Winter
# 1    Feb  27000  Winter
# 2    Mar  25000  Spring
# 3    Apr  29000  Spring
# 4    May  35000  Spring
# 5   June  67000  Summer
# 6   July  78000  Summer
# 7    Aug  67000  Summer
# 8    Sep  56000    Fall
# 9    Oct  56000    Fall
# 10   Nov  56000    Fall
# 11   Dec  60000  Winter

# %%
cate_df=df_stats2.astype('category')
print(cate_df.dtypes)
# Out:
# Month      category
# Sales      category
# Seasons    category
# dtype: object

# %%
cate_df.describe().T
# Out:
#         count unique    top freq
# Month      12     12    Apr    1
# Sales      12      9  56000    3
# Seasons    12      4   Fall    3

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 15. Find the kurtosis for each subject
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
data9={'Name':['Emma','Mia','Sophia','James','John'],
      'Maths':[56,78,78,67,88],
      'Science':[89,87,78,89,78],
      'English':[89,89,76,78,87]}
df_kurtosis=pd.DataFrame(data9)
df_kurtosis
# Out:
#      Name  Maths  Science  English
# 0    Emma     56       89       89
# 1     Mia     78       87       89
# 2  Sophia     78       78       76
# 3   James     67       89       78
# 4    John     88       78       87

# %%
df_kurtosis.kurt()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_13664/625428673.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_kurtosis.kurt()
# Maths     -0.219599
# Science   -3.232332
# English   -2.923881
# dtype: float64

# %% [markdown]
# <a id='merge'></a>
# ## 7. Merge, Join, Concatenate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 16. Merge the given data frames by 'ID' column
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
d1={'ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','Ayoung'],
        'Subject':['Maths','English','Science','Germen','History']}
d2={'ID':[101,102,103,104,105],'Name':['Billy','Brian','Bran','Bryce','Betty'],
        'Subject':['English','Science','Social Science','Germen','History']}
df9=pd.DataFrame(d1)
print(df9)
df10=pd.DataFrame(d2)
print(df10)
# Out:
#     ID    Name  Subject
# 0  101    Alex    Maths
# 1  102     Amy  English
# 2  103   Allen  Science
# 3  104   Alice   Germen
# 4  105  Ayoung  History
#     ID   Name         Subject
# 0  101  Billy         English
# 1  102  Brian         Science
# 2  103   Bran  Social Science
# 3  104  Bryce          Germen
# 4  105  Betty         History

# %%
pd.merge(df9,df10,on='ID')
# Out:
#     ID  Name_x Subject_x Name_y       Subject_y
# 0  101    Alex     Maths  Billy         English
# 1  102     Amy   English  Brian         Science
# 2  103   Allen   Science   Bran  Social Science
# 3  104   Alice    Germen  Bryce          Germen
# 4  105  Ayoung   History  Betty         History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 17. Merge the given data frames by 'ID' and 'Subject'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
d2={'ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','Ayoung'],
        'Subject':['Maths','English','Science','Germen','History']}
d3={'ID':[101,102,103,104,105],'Name':['Billy','Brian','Bran','Bryce','Betty'],
        'Subject':['English','Science','Social Science','Germen','History']}
df9=pd.DataFrame(d2)
print(df9)
df11=pd.DataFrame(d3)
print(df11)
# Out:
#     ID    Name  Subject
# 0  101    Alex    Maths
# 1  102     Amy  English
# 2  103   Allen  Science
# 3  104   Alice   Germen
# 4  105  Ayoung  History
#     ID   Name         Subject
# 0  101  Billy         English
# 1  102  Brian         Science
# 2  103   Bran  Social Science
# 3  104  Bryce          Germen
# 4  105  Betty         History

# %%
pd.merge(df9,df11,on=['ID','Subject'],how='left')
# Out:
#     ID  Name_x  Subject Name_y
# 0  101    Alex    Maths    NaN
# 1  102     Amy  English    NaN
# 2  103   Allen  Science    NaN
# 3  104   Alice   Germen  Bryce
# 4  105  Ayoung  History  Betty

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 18. Perform left merge to only combine values in the column 'Subject' that match
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
d3={'ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','Ayoung'],
        'Subject':['Maths','English','Science','Germen','History']}
d4={'ID':[101,102,103,104,105],'Name':['Billy','Brian','Bran','Bryce','Betty'],
        'Subject':['English','Science','Social Science','Germen','History']}
df13=pd.DataFrame(d3)
print(df13)
df14=pd.DataFrame(d4)
print(df14)
# Out:
#     ID    Name  Subject
# 0  101    Alex    Maths
# 1  102     Amy  English
# 2  103   Allen  Science
# 3  104   Alice   Germen
# 4  105  Ayoung  History
#     ID   Name         Subject
# 0  101  Billy         English
# 1  102  Brian         Science
# 2  103   Bran  Social Science
# 3  104  Bryce          Germen
# 4  105  Betty         History

# %%
pd.merge(df13,df14,on = 'Subject',how='left')
# Out:
#    ID_x  Name_x  Subject   ID_y Name_y
# 0   101    Alex    Maths    NaN    NaN
# 1   102     Amy  English  101.0  Billy
# 2   103   Allen  Science  102.0  Brian
# 3   104   Alice   Germen  104.0  Bryce
# 4   105  Ayoung  History  105.0  Betty

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 19. Perform outer merge to combine values, only if the column 'Subject' match
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
d4={'ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','Ayoung'],
        'Subject':['Maths','English','Science','Germen','History']}
d5={'ID':[101,102,103,104,105],'Name':['Billy','Brian','Bran','Bryce','Betty'],
        'Subject':['English','Science','Social Science','Germen','History']}
df15=pd.DataFrame(d4)
print(df15)
df16=pd.DataFrame(d5)
print(df16)
# Out:
#     ID    Name  Subject
# 0  101    Alex    Maths
# 1  102     Amy  English
# 2  103   Allen  Science
# 3  104   Alice   Germen
# 4  105  Ayoung  History
#     ID   Name         Subject
# 0  101  Billy         English
# 1  102  Brian         Science
# 2  103   Bran  Social Science
# 3  104  Bryce          Germen
# 4  105  Betty         History

# %%
pd.merge(df15,df16,on='Subject',how='outer')
# Out:
#     ID_x  Name_x         Subject   ID_y Name_y
# 0  101.0    Alex           Maths    NaN    NaN
# 1  102.0     Amy         English  101.0  Billy
# 2  103.0   Allen         Science  102.0  Brian
# 3  104.0   Alice          Germen  104.0  Bryce
# 4  105.0  Ayoung         History  105.0  Betty
# 5    NaN     NaN  Social Science  103.0   Bran

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 20. Concatenate rows of two data frames and assign keys
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
data1 ={'ID':[101,102,103,104,105],'Name':['Alex','Amy','Allen','Alice','Ayoung'],
        'Subject':['Maths','English','Science','Germen','History']}

# %%
data2= {'ID':[101,102,103,104,105],'Name':['Billy','Brian','Bran','Bryce','Betty'],
        'Subject':['English','Science','Social Science','Germen','History']}

# %%
df1=pd.DataFrame(data1)
print(df1)
df2=pd.DataFrame(data2)
print(df2)
# Out:
#     ID    Name  Subject
# 0  101    Alex    Maths
# 1  102     Amy  English
# 2  103   Allen  Science
# 3  104   Alice   Germen
# 4  105  Ayoung  History
#     ID   Name         Subject
# 0  101  Billy         English
# 1  102  Brian         Science
# 2  103   Bran  Social Science
# 3  104  Bryce          Germen
# 4  105  Betty         History

# %%
df_concat=pd.concat([df1,df2],axis=0)
df_concat
# Out:
#     ID    Name         Subject
# 0  101    Alex           Maths
# 1  102     Amy         English
# 2  103   Allen         Science
# 3  104   Alice          Germen
# 4  105  Ayoung         History
# 0  101   Billy         English
# 1  102   Brian         Science
# 2  103    Bran  Social Science
# 3  104   Bryce          Germen
# 4  105   Betty         History

# %%
df_concat.keys()
# Out:
# Index(['ID', 'Name', 'Subject'], dtype='object')
